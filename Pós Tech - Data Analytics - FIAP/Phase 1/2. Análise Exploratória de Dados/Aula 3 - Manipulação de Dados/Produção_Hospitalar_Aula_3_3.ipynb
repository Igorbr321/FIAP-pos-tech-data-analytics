# %% [markdown]
# # Analisando Dados - Produção Hospitalar

# %% [markdown]
# ## Pré-processamento de Dados

# %%
# Importando biblioteca pandas.
import pandas as pd

# %%
# Deixando um formato padrão de 2 casas decimais.
pd.options.display.float_format = '{:.2f}'.format

# %%
# Carregando o dataframe, que não está no formato utf-8.
# Usando funções, modificamos para o tipo dos dados do dataframe e excluimos algumas linhas, que não estão em formato tabular.
file_1 = 'A150850189_28_143_208.csv'
file_2 = 'A152918189_28_143_208.csv'

df = pd.read_csv(file_1, sep=";", encoding="ISO-8859-1", skiprows=3, skipfooter=12, decimal=",", thousands=".", engine="python")

# %%
df.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2021/Jan    2021/Fev    2021/Mar  \
# 0        -        -        -  ... 10045624.39 10677245.18 18147121.02
# 1        -        -        -  ...  4175526.06  5282655.42  5699597.78
# 2        -        -        -  ... 27406458.57 22341042.63 27923786.94
# 3        -        -        -  ...  3557821.99  4172285.82  5427226.70
# 4        -        -        -  ... 39042349.46 37113440.70 49625416.13
#
#      2021/Abr    2021/Mai    2021/Jun    2021/Jul    2021/Ago    2021/Set  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 293 entries, Unidade da Federação to Total
# dtypes: float64(170), object(123)
# memory usage: 61.9+ KB

# %%
print(df.dtypes)
# Out:
# Unidade da Federação     object
# 1992/Mar                 object
# 1992/Abr                 object
# 1993/Mai                 object
# 1993/Dez                 object
#                          ...
# 2021/Jun                float64
# 2021/Jul                float64
# 2021/Ago                float64
# 2021/Set                 object
# Total                   float64
# Length: 293, dtype: object

# %%
df.describe()
# Out:
#         2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez      2008/Jan  \
# count      27.00      27.00       27.00       27.00       27.00         27.00
# mean   304952.77  788145.26  2440162.96  5517354.05 12337159.42   76872923.93
# std    392806.00 1071747.56  3421972.10  7767711.29 16345863.65  203345357.97
# min      4113.76   11858.63    43852.67   226661.18   470676.43     808448.39
# 25%     46580.42  139423.94   505778.42  1410610.81  3650090.00    8257222.37
# 50%    179395.82  418053.58  1152115.25  2406035.32  5949408.99   16599004.84
# 75%    392985.52  969999.75  2625635.63  5915821.61 13394973.35   52156843.27
# max   1665349.90 4434168.64 14577395.84 35032259.98 76668547.41 1049827695.26
#
#           2008/Fev     2008/Mar     2008/Abr     2008/Mai  ...     2020/Dez  \
# count        27.00        27.00        27.00        27.00  ...        27.00
# mean   23825025.66  25882844.71  26215278.28  26221049.45  ...  57043175.42
# ...

# %%
# Número de linhas por colunas.
df.shape
# Out:
# (27, 293)

# %% [markdown]
# ## Aula 3 - Manipulação dos Dados

# %% [markdown]
# ### Aula 3.3 - Manipulação dos Dados lll

# %% [markdown]
# > Nessa aula, o professor corrigiu os desafios da segunda aula e deu algumas dicas.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import ScalarFormatter

# %%
df.replace('-', np.nan, inplace=True)

# %%
df_sem_nulos = df.dropna(axis=1)

# %%
df_sem_nulos.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2020/Dez  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  9469279.43
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3820865.83
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 21911210.94
# 3   808448.39   771687.83   876091.18   896952.53  ...  3193708.89
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 37925512.28
#
#      2021/Jan    2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun  \
# ...

# %%
df_sem_nulos.set_index('Unidade da Federação', inplace=True)

# %%
df_sem_nulos = df_sem_nulos.sort_values(by='Total', ascending=False)

# %%
df_sem_nulos.drop(columns='Total', inplace=True)

# %%
colunas_interessadas = df_sem_nulos.columns[6:]

# %%
df_sem_nulos = df_sem_nulos[colunas_interessadas]

# %%
np.random.seed(524387)
#df_sem_nulos.sample(n=7).T.plot(figsize=(10,6))

# %% [markdown]
# ## Desafios

# %% [markdown]
# > Deixar o gráfico mais refinado.
#
# > Plotar somente o seu estado.
#
# > Pesquisar o `sort_index`.
#
# > Pesquisar o casos de dengue e gripe para ver se tem alguma similaridade com os dados.

# %%
# Criar o gráfico
ax = df_sem_nulos.sample(n=7).T.plot(figsize=(12,6))

# Título do Gráfico
plt.title('Unidade da Federação', fontsize=14, fontweight='bold')

# Rótulo dos eixos
ax.set_xlabel('Datas', fontsize=12, fontweight='bold')
ax.set_ylabel('Valor', fontsize=12, fontweight='bold')

# Legenda
plt.legend(title='Estados', title_fontsize=12, labelspacing=1.2, loc='upper left', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 1))

# Configurações do Eixo y
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
ax.ticklabel_format(style='plain', axis='y')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.show()

# %%
df_sem_nulos.head()
# Out:
#                          2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# 35 São Paulo         173062308.33 170621304.31 170389849.75 172513744.39
# 31 Minas Gerais       70301089.50  79119005.51  79046322.41  79268070.12
# 41 Paraná             48855046.46  55611791.07  56115135.82  55574831.93
# 43 Rio Grande do Sul  45897704.82  52928695.92  51972416.77  51679350.79
# 33 Rio de Janeiro     44128159.73  42907909.35  45315594.87  43951349.46
#
#                          2008/Jun     2008/Jul     2008/Ago     2008/Set  \
# Unidade da Federação
# 35 São Paulo         175557604.00 179608674.95 180097396.03 180211608.05
# 31 Minas Gerais       79628284.54  82216960.75  80374117.08  82416883.07
# 41 Paraná             56094754.74  59802402.07  56699001.13  58091985.79
# 43 Rio Grande do Sul  53759674.01  56391647.77  56233758.74  57910170.98
# 33 Rio de Janeiro     44118169.60  44360299.24  42502172.22  43066461.47
#
# ...

# %%
df_sp = df_sem_nulos.loc['35 São Paulo']

# %%
# Criar o gráfico
ax_b = df_sp.T.plot(figsize=(12,6))

# Título do Gráfico
plt.title('Estado de São Paulo', fontsize=12, fontweight='bold')

# Rótulo dos eixos
ax_b.set_ylabel('Valores', fontsize=12, fontweight='bold')
ax_b.set_xlabel('Datas', fontsize=12, fontweight='bold')

# Legenda
plt.legend(title='Estado', title_fontsize=12, labelspacing=1.2, loc='upper left', fontsize=10, frameon=False, bbox_to_anchor=(1.05, 1))

# Configurações do Eixo y
ax_b.yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
ax_b.ticklabel_format(style='plain', axis='y')
ax_b.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.show()

# %% [markdown]
# A função `sort_index` é sada para ordenar os dados em um DataFrame ou Series com base nos índices. É particularmente útil quando você deseja reorganizar os dados por seus rótulos de índice (linhas ou colunas) em ordem crescente ou decrescente.
#
# **Sintaxe**:  `DataFrame.sort_index(axis=0, level=None, ascending=True, inplace=False, kind='quicksort', na_position='last', sort_remaining=True, ignore_index=False, key=None)`
