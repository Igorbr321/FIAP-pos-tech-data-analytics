# %% [markdown]
# # Analisando Dados - Produção Hospitalar

# %% [markdown]
# ## Pré-processamento de Dados

# %%
# Importando biblioteca pandas.
import pandas as pd

# %%
# Deixando um formato padrão de 2 casas decimais.
pd.options.display.float_format = '{:.2f}'.format

# %%
# Carregando o dataframe, que não está no formato utf-8.
# Usando funções, modificamos para o tipo dos dados do dataframe e excluimos algumas linhas, que não estão em formato tabular.
file = ''

df = pd.read_csv(file, sep=";", encoding="ISO-8859-1", skiprows=3, skipfooter=12, decimal=",", thousands=".", engine="python")

# %%
df.head()
# Out:
#   Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 0          11 Rondônia  1388528.39  2931283.42  1541682.52  1525314.96
# 1              12 Acre   902416.00  1497206.26  1794028.48  1730469.42
# 2          13 Amazonas  4735529.42  7118990.57  8196635.49  8259378.42
# 3           14 Roraima   657889.53   777939.31   718688.03   839994.39
# 4              15 Pará 18864744.11 19553758.20 21937342.70 20842829.69
#
#      2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...  \
# 0  1645953.84  1406150.68  3065279.01  3231494.61  3117178.63  ...
# 1  1819443.92  1828496.00  2511754.59  2089107.14  2275708.53  ...
# 2  7831399.90  8477273.62  9368858.72  9352532.70  9363099.35  ...
# 3   862347.96   832440.66   996693.09   894271.18   910424.17  ...
# 4 23249952.88 23240687.56 24002223.56 23341218.03 25172261.32  ...
#
#      2021/Jan    2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun  \
# 0  9858841.18  9806315.07 14946369.28 15552930.66 16269008.71 15380532.08
# 1  3715723.12  3538427.92  4077045.92  6307616.67  6354514.15  3461663.11
# 2 21621697.26 26163677.75 23445832.76 23154039.32 26127701.15 26447055.27
# 3  3266928.47  3519773.73  4437161.10  5171370.92  4266254.94  3103979.88
# 4 38813794.18 39251569.26 40639703.77 46608262.09 55310881.51 48215050.10
#
#      2021/Jul    2021/Ago     2021/Set         Total
# 0 14228814.25 12427865.05  10345616.78 1088059702.25
# 1  4979239.30  4138751.64            -  475290315.34
# 2 24457791.81 22731356.54  19840265.30 2061943006.93
# 3  3743330.65  3781921.16   3150835.05  352546288.71
# 4 45801750.84 43262884.30  14569318.55 4968811817.17
#
# [5 rows x 167 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 167 entries, Unidade da Federação to Total
# dtypes: float64(164), object(3)
# memory usage: 35.4+ KB

# %%
print(df.dtypes)
# Out:
# Unidade da Federação     object
# 2008/Jan                float64
# 2008/Fev                float64
# 2008/Mar                float64
# 2008/Abr                float64
#                          ...
# 2021/Jun                float64
# 2021/Jul                float64
# 2021/Ago                float64
# 2021/Set                 object
# Total                   float64
# Length: 167, dtype: object

# %%
df.describe()
# Out:
#          2008/Jan     2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# count       27.00        27.00        27.00        27.00        27.00
# mean  15126846.64  22710158.12  24594187.35  25431957.83  26511245.91
# std   19159188.30  30879444.07  32516725.69  33339066.25  37540771.63
# min     657889.53    777939.31    718688.03    839994.39    862347.96
# 25%    4740724.30   7060731.59   8041439.31   8526744.11   8531522.65
# 50%    7985142.43  10079928.25  10352238.59  11253833.56  12215107.11
# 75%   17684828.78  25693265.33  29357964.23  32741327.52  31376220.41
# max   91678473.48 148677526.82 156087269.23 161227125.43 187119397.64
#
#           2008/Jun     2008/Jul     2008/Ago     2008/Set     2008/Out  ...  \
# count        27.00        27.00        27.00        27.00        27.00  ...
# mean   27858576.43  28332973.51  27800320.31  27887505.26  27148854.29  ...
# std    38676893.04  39292968.91  37748913.80  38226540.65  36671387.56  ...
# min      832440.66    996693.09    894271.18    910424.17   1191770.32  ...
# 25%     9272741.85   9266086.50   9297840.75   9207727.12   9083121.19  ...
# 50%    12850125.67  12755413.77  12872578.37  12727433.30  12768727.85  ...
# 75%    31755745.04  31805516.06  33353946.49  32015490.68  31268675.55  ...
# max   187291126.07 194398399.48 184854516.35 188636359.55 179706467.00  ...
#
#           2020/Dez     2021/Jan     2021/Fev     2021/Mar     2021/Abr  \
# count        27.00        27.00        27.00        27.00        27.00
# mean   53904471.51  56996463.40  57454833.76  66569186.63  75086973.94
# std    69662378.60  74325371.07  73512919.92  84752667.45  97487952.57
# min     2566919.60   2807807.85   2822559.17   3188210.98   3616822.40
# 25%    17799900.96  18515047.76  18826168.75  21966158.53  24990161.44
# 50%    23886822.89  28074416.33  26581525.53  31831917.45  38410115.30
# 75%    71641328.34  76485863.33  77059910.83  86660408.10  95981235.47
# max   331043717.53 356097158.62 350366878.19 406866741.08 474279794.22
#
#           2021/Mai     2021/Jun     2021/Jul     2021/Ago          Total
# count        27.00        27.00        27.00        27.00          27.00
# mean   79540074.51  82724335.66  81601322.73  75035922.89  6852328259.77
# std   104466080.47 108304829.55 106722619.62  96718616.04  9169897447.11
# min     4266254.94   3103979.88   3743330.65   3781921.16   337181964.14
# 25%    27388451.37  27301366.60  26725147.89  23727258.23  2224263694.82
# 50%    36764212.60  36708007.18  38943213.02  37763607.95  2867428082.03
# 75%   101166979.89 117658565.58 106258390.03 102664947.23  8818298482.19
# max   510118421.51 522748386.07 515461288.66 460348563.01 44290985780.46
#
# [8 rows x 164 columns]

# %%
# Número de linhas por colunas.
df.shape
# Out:
# (27, 167)

# %% [markdown]
# ## Aula 1 - Aquisição e Leitura de Dados Reais

# %% [markdown]
# ### Aula 1.1 - Aquisição e Leitura de Dados Reais l

# %% [markdown]
# > Coletando dados de um site hospitalar para manipular e ler dados reais.

# %% [markdown]
# ### Aula 1.2 - Aquisição e Leitura de Dados Reais ll

# %%
# Na variável df_numeric, seleciona toda as colunas que são diferentes de "Unidade da Federação",
# e muda os tipos delas para float e os valores nelas que forem string, são representados por NaN.
df_numeric = df.loc[:, df.columns != 'Unidade da Federação'].apply(pd.to_numeric, errors='coerce')

# %%
# Concatena a coluna "Unidade da Federação" com a váriavel df_numerica, colocando-a na posição 1.
df = pd.concat([df['Unidade da Federação'], df_numeric], axis=1)

# %%
df.head()
# Out:
#   Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 0          11 Rondônia  1388528.39  2931283.42  1541682.52  1525314.96
# 1              12 Acre   902416.00  1497206.26  1794028.48  1730469.42
# 2          13 Amazonas  4735529.42  7118990.57  8196635.49  8259378.42
# 3           14 Roraima   657889.53   777939.31   718688.03   839994.39
# 4              15 Pará 18864744.11 19553758.20 21937342.70 20842829.69
#
#      2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...  \
# 0  1645953.84  1406150.68  3065279.01  3231494.61  3117178.63  ...
# 1  1819443.92  1828496.00  2511754.59  2089107.14  2275708.53  ...
# 2  7831399.90  8477273.62  9368858.72  9352532.70  9363099.35  ...
# 3   862347.96   832440.66   996693.09   894271.18   910424.17  ...
# 4 23249952.88 23240687.56 24002223.56 23341218.03 25172261.32  ...
#
#      2021/Jan    2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun  \
# 0  9858841.18  9806315.07 14946369.28 15552930.66 16269008.71 15380532.08
# 1  3715723.12  3538427.92  4077045.92  6307616.67  6354514.15  3461663.11
# 2 21621697.26 26163677.75 23445832.76 23154039.32 26127701.15 26447055.27
# 3  3266928.47  3519773.73  4437161.10  5171370.92  4266254.94  3103979.88
# 4 38813794.18 39251569.26 40639703.77 46608262.09 55310881.51 48215050.10
#
#      2021/Jul    2021/Ago    2021/Set         Total
# 0 14228814.25 12427865.05 10345616.78 1088059702.25
# 1  4979239.30  4138751.64         NaN  475290315.34
# 2 24457791.81 22731356.54 19840265.30 2061943006.93
# 3  3743330.65  3781921.16  3150835.05  352546288.71
# 4 45801750.84 43262884.30 14569318.55 4968811817.17
#
# [5 rows x 167 columns]

# %%
# Pegamos todas as colunas e tiramos a média delas com excessão da primeira,
# que é uma string.
media_columns = df.iloc[:, 1:].mean()

# %%
media_columns.head()
# Out:
# 2008/Jan   15126846.64
# 2008/Fev   22710158.12
# 2008/Mar   24594187.35
# 2008/Abr   25431957.83
# 2008/Mai   26511245.91
# dtype: float64

# %% [markdown]
# ### Desafio - Coletar a última data do Dataframe.

# %%
# Essa váriavel coleta o último ano e mês disponibilizado pelos dados,
# eliminando a coluna que não iremos utilizar.
df_final_column = df.iloc[:, -2]

# %%
df_final_column.head()
# Out:
# 0   10345616.78
# 1           NaN
# 2   19840265.30
# 3    3150835.05
# 4   14569318.55
# Name: 2021/Set, dtype: float64
