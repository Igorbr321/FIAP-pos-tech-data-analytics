# %% [markdown]
# # Analisando Dados - Produção Hospitalar

# %% [markdown]
# ## Pré-processamento de Dados

# %%
# Importando biblioteca pandas.
import pandas as pd

# %%
# Deixando um formato padrão de 2 casas decimais.
pd.options.display.float_format = '{:.2f}'.format

# %%
# Carregando o dataframe, que não está no formato utf-8.
# Usando funções, modificamos para o tipo dos dados do dataframe e excluimos algumas linhas, que não estão em formato tabular.
file_1 = 'A150850189_28_143_208.csv'
file_2 = 'A152918189_28_143_208.csv'

df = pd.read_csv(file_1, sep=";", encoding="ISO-8859-1", skiprows=3, skipfooter=12, decimal=",", thousands=".", engine="python")

# %%
df.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2021/Jan    2021/Fev    2021/Mar  \
# 0        -        -        -  ... 10045624.39 10677245.18 18147121.02
# 1        -        -        -  ...  4175526.06  5282655.42  5699597.78
# 2        -        -        -  ... 27406458.57 22341042.63 27923786.94
# 3        -        -        -  ...  3557821.99  4172285.82  5427226.70
# 4        -        -        -  ... 39042349.46 37113440.70 49625416.13
#
#      2021/Abr    2021/Mai    2021/Jun    2021/Jul    2021/Ago    2021/Set  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 293 entries, Unidade da Federação to Total
# dtypes: float64(170), object(123)
# memory usage: 61.9+ KB

# %%
print(df.dtypes)
# Out:
# Unidade da Federação     object
# 1992/Mar                 object
# 1992/Abr                 object
# 1993/Mai                 object
# 1993/Dez                 object
#                          ...
# 2021/Jun                float64
# 2021/Jul                float64
# 2021/Ago                float64
# 2021/Set                 object
# Total                   float64
# Length: 293, dtype: object

# %%
df.describe()
# Out:
#         2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez      2008/Jan  \
# count      27.00      27.00       27.00       27.00       27.00         27.00
# mean   304952.77  788145.26  2440162.96  5517354.05 12337159.42   76872923.93
# std    392806.00 1071747.56  3421972.10  7767711.29 16345863.65  203345357.97
# min      4113.76   11858.63    43852.67   226661.18   470676.43     808448.39
# 25%     46580.42  139423.94   505778.42  1410610.81  3650090.00    8257222.37
# 50%    179395.82  418053.58  1152115.25  2406035.32  5949408.99   16599004.84
# 75%    392985.52  969999.75  2625635.63  5915821.61 13394973.35   52156843.27
# max   1665349.90 4434168.64 14577395.84 35032259.98 76668547.41 1049827695.26
#
#           2008/Fev     2008/Mar     2008/Abr     2008/Mai  ...     2020/Dez  \
# count        27.00        27.00        27.00        27.00  ...        27.00
# mean   23825025.66  25882844.71  26215278.28  26221049.45  ...  57043175.42
# ...

# %%
# Número de linhas por colunas.
df.shape
# Out:
# (27, 293)

# %% [markdown]
# ## Aula 3 - Manipulação dos Dados

# %% [markdown]
# ### Aula 3.2 - Manipulação dos Dados ll

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import ScalarFormatter

# %%
df.replace("-", np.nan, inplace=True)

# %%
df_sem_nulos = df.dropna(axis=1)

# %%
df_sem_nulos.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2020/Dez  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  9469279.43
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3820865.83
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 21911210.94
# 3   808448.39   771687.83   876091.18   896952.53  ...  3193708.89
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 37925512.28
#
#      2021/Jan    2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun  \
# ...

# %%
df_sem_nulos_b = df_sem_nulos.set_index('Unidade da Federação')

# %%
df_sem_nulos_b.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
df_sem_nulos_b.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
df_sem_nulos_b.sample(n=7).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
df_sem_nulos_b.drop(columns=['Total'], inplace=True)

# %%
df_sem_nulos_b.sample(n=7).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
import numpy as np

np.random.seed(524387)
df_sem_nulos_b.sample(n=7)
# Out:
#                       2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 17 Tocantins           4113.76   76633.06   343702.61  1068685.94  3022200.87
# 26 Pernambuco        400640.85 1088340.42  2973553.48  6699828.82 16919031.39
# 31 Minas Gerais      971394.37 2861781.50 10018011.35 21730281.63 43429517.54
# 22 Piauí             220788.25  353468.67  1078182.68  2406035.32  4929772.93
# 25 Paraíba            97352.78  368130.43  1002088.64  2149873.40  5448177.36
# 29 Bahia             135146.36  448349.75  1382038.11  3348779.62 11948984.56
# 42 Santa Catarina    693955.05 1092964.12  3562300.82  7578502.38 14772555.10
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 17 Tocantins           5136474.61  5051932.07  5200151.87  5343714.73
# 26 Pernambuco         51279301.86 26222079.10 30716361.81 30589332.79
# 31 Minas Gerais      206493861.30 70301089.50 79119005.51 79046322.41
# ...

# %%
df_sem_nulos_b['Total'] = df_sem_nulos_b.sum(axis=1)
df_sem_nulos_b.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %% [markdown]
# ### Desafios:
#
# > Ordenar o DataFrame para que na primeira linha tenha a linha com maior gasto, e na última linha o valor com menor gasto (Ordenação).
#
# > Adicionar uma coluna com a região de cada estado
#
# > Adicionar seu estado no DataFrame

# %%
df_sem_nulos = df.dropna(axis=1)

# %%
coluna_total = df_sem_nulos['Total']

# %%
df_sn = df_sem_nulos.drop(columns=['Total'])

# %%
df_sn.insert(0, 'Total', coluna_total)

# %%
df_sn = df_sn.sort_values(by='Total', ascending=False)

# %%
regioes = {
    '35 São Paulo': 'Sudeste',
    '31 Minas Gerais': 'Sudeste',
    '41 Paraná': 'Sul',
    '43 Rio Grande do Sul': 'Sul',
    '33 Rio de Janeiro': 'Sudeste',
    '29 Bahia': 'Nordeste',
    '26 Pernambuco': 'Nordeste',
    '42 Santa Catarina': 'Sul',
    '23 Ceará': 'Nordeste',
    '52 Goiás': 'Centro-Oeste',
    '15 Pará': 'Norte',
    '21 Maranhão': 'Nordeste',
    '32 Espírito Santo': 'Sudeste',
    '24 Rio Grande do Norte': 'Nordeste',
    '25 Paraíba': 'Nordeste',
    '53 Distrito Federal': 'Centro-Oeste',
    '50 Mato Grosso do Sul': 'Centro-Oeste',
    '22 Piauí': 'Nordeste',
    '27 Alagoas': 'Nordeste',
    '51 Mato Grosso': 'Centro-Oeste',
    '13 Amazonas': 'Norte',
    '28 Sergipe': 'Nordeste',
    '17 Tocantins': 'Norte',
    '11 Rondônia': 'Norte',
    '12 Acre': 'Norte',
    '14 Roraima': 'Norte',
    '16 Amapá': 'Norte'
}

# %%
df_sn['Regiao'] = df_sn['Unidade da Federação'].map(regioes)

# %%
df_sn = df_sn.set_index('Unidade da Federação')

# %%
coluna_regiao = df_sn['Regiao']

# %%
df_sn = df_sn.drop(columns=['Regiao'], axis=1)

# %%
df_sn.insert(1, 'Regiao', coluna_regiao)

# %%
df_sn.head()
# Out:
#                               Total   Regiao   2007/Ago   2007/Set  \
# Unidade da Federação
# 35 São Paulo         44290790025.14  Sudeste 1665349.90 4434168.64
# 31 Minas Gerais      21899546392.60  Sudeste  971394.37 2861781.50
# 41 Paraná            15672157558.11      Sul  554800.22 1431708.01
# 43 Rio Grande do Sul 13613341350.00      Sul 1049252.33 3182913.14
# 33 Rio de Janeiro    11131868548.73  Sudeste  469469.34  921646.57
#
#                         2007/Out    2007/Nov    2007/Dez      2008/Jan  \
# Unidade da Federação
# 35 São Paulo         14577395.84 35032259.98 76668547.41 1049827695.26
# 31 Minas Gerais      10018011.35 21730281.63 43429517.54  206493861.30
# 41 Paraná             4630402.44 11120030.79 28790722.87   58081334.45
# 43 Rio Grande do Sul  8571312.11 16592432.80 30134255.70   51064610.03
# 33 Rio de Janeiro     2994664.57  7250528.08 13627123.27  252175779.88
#
#                          2008/Fev     2008/Mar  ...     2020/Nov     2020/Dez  \
# ...
