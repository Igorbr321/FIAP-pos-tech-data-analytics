# %% [markdown]
# # Analisando Dados - Produção Hospitalar

# %%
import pandas as pd

# %%
gastos_e_pop = pd.read_pickle(r'C:\Users\Usuario\Downloads\FIAP-pos-tech-data-analytics\Pós Tech - Data Analytics - FIAP\Phase 1\3. Visualização de Dados - PEN\Aula 1 - Tratamento, exploração e visualização\gastos_e_pop.pkl')

# %%
gastos_e_pop.head()
# Out:
#                 populacao_estimativa    2021/Ago
# uf
# São Paulo                   45973190  301.986342
# Minas Gerais                21322692  139.157824
# Rio de Janeiro              17219679   94.137361
# Bahia                       14850513   61.645689
# Paraná                      11824665   91.187723
